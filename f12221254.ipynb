# %%
import numpy as np
import pandas as pd
#import pandas_profiling as pdp
import matplotlib.pyplot as plt
import seaborn as sns
# This line tells the notebook to show plots inside of the notebook
# %matplotlib inline

# %%
file=r"D:\EXCELL\flight.csv"
data = pd.read_csv(file, encoding = 'unicode_escape')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13288\678517468.py:2: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file, encoding = 'unicode_escape')

# %%
data
# Out:
#         Unnamed: 0    airline   flight source_city departure_time stops  \
# 0                0   SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1   SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2    AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3    Vistara   UK-995       Delhi        Morning  zero
# 4                4    Vistara   UK-963       Delhi        Morning  zero
# ...            ...        ...      ...         ...            ...   ...
# 301201     1300218    Vistara   UK-747       Delhi  Early_Morning   one
# 301202     1300219  Air_India   AI-512       Delhi      Afternoon   one
# 301203     1300220  Air_India   AI-537       Delhi        Evening   one
# 301204     1300221    Vistara   UK-977       Delhi        Evening  zero
# 301205     1300222    Vistara   UK-809       Delhi        Evening   one
#
#          arrival_time destination_city    class  duration  days_left  price  \
# ...

# %%
d=data.copy()

# %%
d
# Out:
#         Unnamed: 0    airline   flight source_city departure_time stops  \
# 0                0   SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1   SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2    AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3    Vistara   UK-995       Delhi        Morning  zero
# 4                4    Vistara   UK-963       Delhi        Morning  zero
# ...            ...        ...      ...         ...            ...   ...
# 301201     1300218    Vistara   UK-747       Delhi  Early_Morning   one
# 301202     1300219  Air_India   AI-512       Delhi      Afternoon   one
# 301203     1300220  Air_India   AI-537       Delhi        Evening   one
# 301204     1300221    Vistara   UK-977       Delhi        Evening  zero
# 301205     1300222    Vistara   UK-809       Delhi        Evening   one
#
#          arrival_time destination_city    class  duration  days_left  price  \
# ...

# %%
d.shape
# Out:
# (301206, 13)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301206 entries, 0 to 301205
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        301206 non-null  int64
#  1   airline           300754 non-null  object
#  2   flight            301206 non-null  object
#  3   source_city       301206 non-null  object
#  4   departure_time    301206 non-null  object
#  5   stops             301206 non-null  object
#  6   arrival_time      301206 non-null  object
#  7   destination_city  301206 non-null  object
#  8   class             301006 non-null  object
#  9   duration          300956 non-null  float64
#  10  days_left         301206 non-null  int64
#  11  price             301106 non-null  object
#  12  date              358 non-null     object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 29.9+ MB

# %%
d.isnull().sum()
# Out:
# Unnamed: 0               0
# airline                452
# flight                   0
# source_city              0
# departure_time           0
# stops                    0
# arrival_time             0
# destination_city         0
# class                  200
# duration               250
# days_left                0
# price                  100
# date                300848
# dtype: int64

# %%
d['source_city'].unique()
# Out:
# array(['Delhi', 'Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai'],
#       dtype=object)

# %%
d['destination_city'].unique()
# Out:
# array(['Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai', 'Delhi'],
#       dtype=object)

# %%
d.drop('Unnamed: 0', axis=1, inplace=True)

# %%
d.columns
# Out:
# Index(['airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price', 'date'],
#       dtype='object')

# %%
d.isnull().sum()
# Out:
# airline                452
# flight                   0
# source_city              0
# departure_time           0
# stops                    0
# arrival_time             0
# destination_city         0
# class                  200
# duration               250
# days_left                0
# price                  100
# date                300848
# dtype: int64

# %%
d['duration'].fillna(0, inplace=True)
d['class'].fillna('Unknown', inplace=True)
d['airline'].fillna('Unknown', inplace=True)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301206 entries, 0 to 301205
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           301206 non-null  object
#  1   flight            301206 non-null  object
#  2   source_city       301206 non-null  object
#  3   departure_time    301206 non-null  object
#  4   stops             301206 non-null  object
#  5   arrival_time      301206 non-null  object
#  6   destination_city  301206 non-null  object
#  7   class             301206 non-null  object
#  8   duration          301206 non-null  float64
#  9   days_left         301206 non-null  int64
#  10  price             301106 non-null  object
#  11  date              358 non-null     object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 27.6+ MB

# %%
d
# Out:
#           airline   flight source_city departure_time stops   arrival_time  \
# 0        SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1        SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2         AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3         Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4         Vistara   UK-963       Delhi        Morning  zero        Morning
# ...           ...      ...         ...            ...   ...            ...
# 301201    Vistara   UK-747       Delhi  Early_Morning   one          Night
# 301202  Air_India   AI-512       Delhi      Afternoon   one          Night
# 301203  Air_India   AI-537       Delhi        Evening   one        Morning
# 301204    Vistara   UK-977       Delhi        Evening  zero          Night
# 301205    Vistara   UK-809       Delhi        Evening   one          Night
#
# ...

# %%
d['departure_time'] = d['departure_time'].str.replace('Early_Morning', 'Morning')
d['arrival_time'] = d['arrival_time'].str.replace('Early_Morning', 'Morning')

# %%
d['arrival_time'] = d['arrival_time'].str.replace('Late_Night', 'Night')
d['departure_time'] = d['departure_time'].str.replace('Late_Night', 'Night')

# %%
d['airline'] = d['airline'].str.replace('Air_India', 'Air India')

d['airline'] = d['airline'].str.replace('AirAsia', 'Air Asia')
d['airline'] = d['airline'].str.replace('GO_FIRST', 'Go First')

# %%
d['arrival_time'].unique()
# Out:
# array(['Night', 'Morning', 'Afternoon', 'Evening'], dtype=object)

# %%
d['departure_time'].unique()
# Out:
# array(['Evening', 'Morning', 'Afternoon', 'Night'], dtype=object)

# %%
d['departure_time'].unique()
# Out:
# array(['Evening', 'Morning', 'Afternoon', 'Night'], dtype=object)

# %%
d['class'].unique()
# Out:
# array(['Economy', 'Business', 'Unknown'], dtype=object)

# %%
d['source_city'].unique()
# Out:
# array(['Delhi', 'Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai'],
#       dtype=object)

# %%
d['source_city'].unique()
# Out:
# array(['Delhi', 'Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai'],
#       dtype=object)

# %%
d['class'].unique()
# Out:
# array(['Economy', 'Business', 'Unknown'], dtype=object)

# %%
d['airline'].unique()
# Out:
# array(['SpiceJet', 'Air Asia', 'Vistara', 'Go First', 'Indigo',
#        'Air India', 'Unknown'], dtype=object)

# %%
# Duplicate values
d.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 301201    False
# 301202    False
# 301203    False
# 301204    False
# 301205    False
# Length: 301206, dtype: bool

# %%
# Filtering out the duplicate entries
d = d[~d.duplicated()]
d[d.duplicated()]
# Out:
# Empty DataFrame
# Columns: [airline, flight, source_city, departure_time, stops, arrival_time, destination_city, class, duration, days_left, price, date]
# Index: []

# %%
d
# Out:
#           airline   flight source_city departure_time stops arrival_time  \
# 0        SpiceJet  SG-8709       Delhi        Evening  zero        Night
# 1        SpiceJet  SG-8157       Delhi        Morning  zero      Morning
# 2        Air Asia   I5-764       Delhi        Morning  zero      Morning
# 3         Vistara   UK-995       Delhi        Morning  zero    Afternoon
# 4         Vistara   UK-963       Delhi        Morning  zero      Morning
# ...           ...      ...         ...            ...   ...          ...
# 301201    Vistara   UK-747       Delhi        Morning   one        Night
# 301202  Air India   AI-512       Delhi      Afternoon   one        Night
# 301203  Air India   AI-537       Delhi        Evening   one      Morning
# 301204    Vistara   UK-977       Delhi        Evening  zero        Night
# 301205    Vistara   UK-809       Delhi        Evening   one        Night
#
#        destination_city    class  duration  days_left  price        date
# ...

# %%
d.describe()
# Out:
#             duration      days_left
# count  301177.000000  301177.000000
# mean       12.226731      26.041647
# std         7.303048      13.565459
# min         0.000000       1.000000
# 25%         6.830000      15.000000
# 50%        11.250000      26.000000
# 75%        16.170000      38.000000
# max       622.250000      49.000000

# %%
# Changing the data type
d['price'] = pd.to_numeric(d['price'], errors = 'coerce')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13288\3873683192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['price'] = pd.to_numeric(d['price'], errors = 'coerce')

# %%
d.describe()
# Out:
#             duration      days_left         price
# count  301177.000000  301177.000000  3.010790e+05
# mean       12.226731      26.041647  2.110409e+04
# std         7.303048      13.565459  2.544395e+04
# min         0.000000       1.000000  1.105000e+03
# 25%         6.830000      15.000000  4.788000e+03
# 50%        11.250000      26.000000  7.439000e+03
# 75%        16.170000      38.000000  4.252100e+04
# max       622.250000      49.000000  2.512780e+06

# %% [markdown]
# # Max and Min prices in the given data

# %%
# Get the maximum price
max_price = d['price'].max()
print(f"Maximum price: {max_price}")

# Get the minimum price
min_price = d['price'].min()
print(f"Minimum price: {min_price}")
# Out:
# Maximum price: 2512780.0
# Minimum price: 1105.0

# %%
bins = [0, 5000, 10000, 15000, np.inf]
labels = ['Budget-friendly', 'Mid-range', 'Premium', 'Luxury']
d['price_bins'] = pd.cut(d['price'], bins=bins, labels=labels)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13288\1106095733.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['price_bins'] = pd.cut(d['price'], bins=bins, labels=labels)

# %%
d
# Out:
#           airline   flight source_city departure_time stops arrival_time  \
# 0        SpiceJet  SG-8709       Delhi        Evening  zero        Night
# 1        SpiceJet  SG-8157       Delhi        Morning  zero      Morning
# 2        Air Asia   I5-764       Delhi        Morning  zero      Morning
# 3         Vistara   UK-995       Delhi        Morning  zero    Afternoon
# 4         Vistara   UK-963       Delhi        Morning  zero      Morning
# ...           ...      ...         ...            ...   ...          ...
# 301201    Vistara   UK-747       Delhi        Morning   one        Night
# 301202  Air India   AI-512       Delhi      Afternoon   one        Night
# 301203  Air India   AI-537       Delhi        Evening   one      Morning
# 301204    Vistara   UK-977       Delhi        Evening  zero        Night
# 301205    Vistara   UK-809       Delhi        Evening   one        Night
#
#        destination_city    class  duration  days_left    price        date  \
# ...

# %%
bins = [0, 60, 120, 180, 240, np.inf]
labels = ['Very Short (<10min)', 'Short (10-30min)', 'Medium (30-60min)', 'Long (1-2hrs)', 'Very Long (>2hrs)']
d['duration_bins'] = pd.cut(d['duration']*60, bins=bins, labels=labels)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13288\1065467135.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['duration_bins'] = pd.cut(d['duration']*60, bins=bins, labels=labels)

# %%
d
# Out:
#           airline   flight source_city departure_time stops arrival_time  \
# 0        SpiceJet  SG-8709       Delhi        Evening  zero        Night
# 1        SpiceJet  SG-8157       Delhi        Morning  zero      Morning
# 2        Air Asia   I5-764       Delhi        Morning  zero      Morning
# 3         Vistara   UK-995       Delhi        Morning  zero    Afternoon
# 4         Vistara   UK-963       Delhi        Morning  zero      Morning
# ...           ...      ...         ...            ...   ...          ...
# 301201    Vistara   UK-747       Delhi        Morning   one        Night
# 301202  Air India   AI-512       Delhi      Afternoon   one        Night
# 301203  Air India   AI-537       Delhi        Evening   one      Morning
# 301204    Vistara   UK-977       Delhi        Evening  zero        Night
# 301205    Vistara   UK-809       Delhi        Evening   one        Night
#
#        destination_city    class  duration  days_left    price        date  \
# ...

# %%
d.describe()
# Out:
#             duration      days_left         price
# count  301177.000000  301177.000000  3.010790e+05
# mean       12.226731      26.041647  2.110409e+04
# std         7.303048      13.565459  2.544395e+04
# min         0.000000       1.000000  1.105000e+03
# 25%         6.830000      15.000000  4.788000e+03
# 50%        11.250000      26.000000  7.439000e+03
# 75%        16.170000      38.000000  4.252100e+04
# max       622.250000      49.000000  2.512780e+06

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# ## **DURATION DISTRIBUTION**

# %%
import matplotlib.pyplot as plt

plt.hist(d['duration'], bins=70)
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')
plt.title('Duration Distribution')
plt.show()

# %% [markdown]
# ## **Duration vs. Price**

# %%
sns.scatterplot(x='duration', y='price', hue='duration_bins', data=d)
plt.xlabel('Duration (minutes)')
plt.ylabel('Price')
plt.title('Duration vs. Price')
plt.show()

# %% [markdown]
# ## **Price Distribution by Duration Bin**

# %%
sns.boxplot(x='duration_bins', y='price', data=d,flierprops={'markersize': 5})
plt.xlabel('Duration Bin')
plt.ylabel('Price')
plt.title('Price Distribution by Duration Bin')
plt.figure(figsize=(12, 6))
plt.show()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ## **Airline-wise Duration Distribution**

# %%
sns.boxplot(x='airline', y='duration', data=d)
plt.xlabel('Airline')
plt.ylabel('Duration (minutes)')
plt.title('Airline-wise Duration Distribution')
plt.show()

# %% [markdown]
# # **Here are the updated graphs focused on airlines:**

# %% [markdown]
# ## **Top Airlines by Number of Flights**

# %%
plt.figure(figsize=(10, 6))
ax=sns.countplot(x='airline', data=d)
plt.title('Top Airlines by Number of Flights')
plt.xlabel('Airline')
plt.ylabel('Number of Flights')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=18)
plt.show()

# %% [markdown]
# ## **Duration Distribution by Airline**

# %%
sns.violinplot(x='airline', y='duration', data=d, inner='quartile')
plt.xlabel('Airline')
plt.ylabel('Duration (minutes)')
plt.title('Duration Distribution by Airline')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# ## **Airline Distribution by Class**

# %%
ax=sns.countplot(x='class', hue='airline', data=d)
plt.xlabel('Class')
plt.ylabel('Number of Flights')
plt.title('Airline Distribution by Class')
plt.show()

# %% [markdown]
# ## *Price Distribution by Airline*

# %%
sns.boxplot(x='airline', y='price', data=d, flierprops={'markersize': 6})  # Increased marker size
plt.xlabel('Airline')
plt.ylabel('Price')
plt.title('Price Distribution by Airline')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# ## Average Price by Airline Stocked Graph

# %%
plt.figure(figsize=(8, 4))
ax=sns.barplot(x='airline', y='price', data=d, errorbar='sd')
plt.title('Average Price by Airline')
plt.xlabel('Airline')
plt.ylabel('Price')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height().round(0)), 
            ha="center", va="bottom", size=10)
plt.show()

# %% [markdown]
# ## **Duration vs. Price by Airline**

# %%
sns.scatterplot(x='duration', y='price', hue='airline', data=d)
plt.xlabel('Duration (minutes)')
plt.ylabel('Price')
plt.title('Duration vs. Price by Airline')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# # **Here are the updated graphs focused on flights:**

# %% [markdown]
# ## *Flight Duration Distribution*

# %%
plt.hist(d['duration'], bins=50)
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')
plt.title('Flight Duration Distribution')
plt.figure(figsize=(12, 6))  # Increased figure size
#plt.xticks(range(0, 120, 10))  # Increased x-axis tick range
plt.show()

# %% [markdown]
# ## *Flight Price Distribution*

# %%
plt.hist(d['price'], bins=50)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Flight Price Distribution')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# ## *Flight Duration vs. Price*

# %%
sns.scatterplot(x='duration', y='price', data=d)
plt.xlabel('Duration (minutes)')
plt.ylabel('Price')
plt.title('Flight Duration vs. Price')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# ## *Flight Departure Time Distribution*

# %%
plt.hist(d['departure_time'], bins=24)
plt.xlabel('Departure Time (hour)')
plt.ylabel('Frequency')
plt.title('Flight Departure Time Distribution')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# ## *Flight Arrival Time Distribution*

# %%
plt.hist(d['arrival_time'], bins=24)
plt.xlabel('Arrival Time (hour)')
plt.ylabel('Frequency')
plt.title('Flight Arrival Time Distribution')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# # Here are the updated graphs focused on flights by source city

# %% [markdown]
# ## Flight Duration Distribution by Source City

# %%
sns.violinplot(x='source_city', y='duration', data=d, inner='quartile')
plt.xlabel('Source City')
plt.ylabel('Duration (minutes)')
plt.title('Flight Duration Distribution by Source City')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# ## *Flight Price Distribution by Source City*

# %%
sns.boxplot(x='source_city', y='price', data=d, flierprops={'markersize': 6})  # Increased marker size
plt.xlabel('Source City')
plt.ylabel('Price')
plt.title('Flight Price Distribution by Source City')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# ## *Top 10 Source Cities by Flight Frequency*

# %%
source_city_counts = d['source_city'].value_counts().head(10)
plt.barh(source_city_counts.index, source_city_counts.values)
plt.xlabel('Frequency')
plt.ylabel('Source City')
plt.title('Top 10 Source Cities by Flight Frequency')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()
source_city_counts = d['source_city'].value_counts().head(10)
plt.bar(source_city_counts.index, source_city_counts.values)
plt.xlabel('Frequency')
plt.ylabel('Source City')
plt.title('Top 10 Source Cities by Flight Frequency')
plt.figure(figsize=(12, 6))  # Increased figure size
plt.show()

# %% [markdown]
# # *Here are some graphs focused on departure time:*

# %% [markdown]
# ## *Top 10 Departure Times*

# %%
top_departure_times = d['departure_time'].value_counts().head(10)
plt.bar(top_departure_times.index, top_departure_times.values)
plt.xlabel('Departure Time')
plt.ylabel('Frequency')
plt.title('Top 10 Departure Times')
plt.show()

# %%
d['stops'].value_counts()
# Out:
# stops
# one            251877
# zero            36013
# two_or_more     13287
# Name: count, dtype: int64

# %% [markdown]
# # *Here are some graphs to visualize the data for stops:*

# %% [markdown]
# ## **Stops frequency**

# %%
stops = d['stops'].value_counts()
plt.bar(stops.index, stops.values)
plt.xlabel('Number of Stops')
plt.ylabel('Frequency')
plt.title('Stop Frequency')
plt.show()

# %% [markdown]
# ## *Stops Distribution*

# %%
ax=sns.countplot(x='stops', data=d)
plt.xlabel('Number of Stops')
plt.ylabel('Frequency')
plt.title('Stop Distribution')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=10)
plt.show()

# %% [markdown]
# ## **Stop Proportion**

# %%
stops_proportion = d['stops'].value_counts(normalize=True) * 100
plt.bar(stops_proportion.index, stops_proportion.values)
plt.xlabel('Number of Stops')
plt.ylabel('Proportion (%)')
plt.title('Stop Proportion')
plt.show()

# %% [markdown]
# ## **stops by Airline**

# %%
ax=sns.countplot(x='stops', hue='airline', data=d)
plt.xlabel('Number of Stops')
plt.ylabel('Frequency')
plt.title('Stops by Airline')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=7)
plt.show()

# %% [markdown]
# ## **Stops by Departure Time**

# %%
ax=sns.countplot(x='stops', hue='departure_time', data=d)
plt.xlabel('Number of Stops')
plt.ylabel('Frequency')
plt.title('Stops by Departure Time')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=8)
plt.show()

# %% [markdown]
# ## **Stops by Arrival Time**

# %%
ax=sns.countplot(x='stops', hue='arrival_time', data=d)
plt.xlabel('Number of Stops')
plt.ylabel('Frequency')
plt.title('Stops by Arrival Time')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=8)
plt.show()

# %% [markdown]
# ## **Stops by Class**

# %%
ax=sns.countplot(x='stops', hue='class', data=d)
plt.xlabel('Number of Stops')
plt.ylabel('Frequency')
plt.title('Stops by Class')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=10)
plt.show()

# %% [markdown]
# ## **Stops by Duration**

# %%
sns.scatterplot(x='duration', y='stops', data=d)
plt.xlabel('Duration (hours)')
plt.ylabel('Number of Stops')
plt.title('Stops by Duration')
plt.show()

# %% [markdown]
# # **Here are some graphs to visualize the relationships between destination cities and other factors:**

# %% [markdown]
# ## *Destination City Distribution*

# %%
ax=sns.countplot(x='destination_city', data=d)
plt.xlabel('Destination City')
plt.ylabel('Number of Flights')
plt.title('Destination City Distribution')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=10)
plt.show()

# %% [markdown]
# ## **Top 10 Destination Cities**

# %%
top_cities = d['destination_city'].value_counts().head(5)

ax=sns.barplot(x=top_cities.index, y=top_cities.values)
plt.xlabel('Destination City')
plt.ylabel('Number of Flights')
plt.title('Top 10 Destination Cities')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=10)
plt.show()

# %% [markdown]
# ## **Destination City by Airline**

# %%
sns.countplot(x='destination_city', hue='airline', data=d)
plt.xlabel('Destination City')
plt.ylabel('Number of Flights')
plt.title('Destination City by Airline')
plt.show()

# %% [markdown]
# ## **Destination City by Source City**

# %%
sns.countplot(x='destination_city', hue='source_city', data=d)
plt.xlabel('Destination City')
plt.ylabel('Number of Flights')
plt.title('Destination City by source City')
plt.show()

# %% [markdown]
# # **Here are some graphs to visualize the relationships between class and other factors**

# %% [markdown]
# ## **Class Distribution**

# %%
ax=sns.countplot(x='class', data=d)
plt.xlabel('Class')
plt.ylabel('Number of Passengers')
plt.title('Class Distribution')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=10)
plt.show()

# %% [markdown]
# ## **Class Distribution / pie chart**

# %%
class_counts = d['class'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%')
plt.title('Class Distribution')
plt.show()

# %% [markdown]
# ## Relationship between Class and Price

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='class', y='price', data=d)
plt.title('Relationship between Class and Price')
plt.xlabel('Class')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## **Class by Airline**

# %%
ax=sns.countplot(x='airline', hue='class', data=d)
plt.xlabel('Airline')
plt.ylabel('Number of Passengers')
plt.title('Class by Airline')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=7)
plt.show()

# %% [markdown]
# ## **Class by Departure City**

# %%
sns.countplot(x='source_city', hue='class', data=d)
plt.xlabel('source City')
plt.ylabel('Number of Passengers')
plt.title('Class by source City')
plt.show()

# %% [markdown]
# ## **Class by destination City**

# %%
sns.countplot(x='destination_city', hue='class', data=d)
plt.xlabel('Destination City')
plt.ylabel('Number of Passengers')
plt.title('Class by Destination City')
plt.show()

# %% [markdown]
# # **Here are some graphs to visualize the relationships between duration and other factors**

# %% [markdown]
# ## *Duration vs Price*

# %%
plt.figure(figsize=(8, 6))
plt.scatter(d['duration'], d['price'])
plt.title('Duration vs Price')
plt.xlabel('Duration')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## *Duration bins*

# %%
duration_bins_counts = d['duration_bins'].value_counts()
plt.figure(figsize=(6, 10))
plt.pie(duration_bins_counts, labels=duration_bins_counts.index, autopct='%1.1f%%')
plt.title('Duration Bins Distribution')
plt.show()

# %% [markdown]
# ## **a heatmap for duration vs days left**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(d[['duration', 'days_left']].corr(), annot=True, cmap='coolwarm', square=True)
plt.title('Duration vs Days Left')
plt.show()

# %% [markdown]
# ## **Average Duration by Stop**

# %%
plt.figure(figsize=(8, 6))
d.groupby('stops')['duration'].mean().plot(kind='bar')
plt.title('Average Duration by Stop')
plt.xlabel('Number of Stops')
plt.ylabel('Average Duration (hours)')
plt.show()

# %% [markdown]
# ## **Average duration by class**

# %%
plt.figure(figsize=(8, 6))
d.groupby('class')['duration'].mean().plot(kind='bar')
plt.title('Average Duration by Class')
plt.xlabel('Class')
plt.ylabel('Average Duration (hours)')
plt.show()

# %% [markdown]
# ## **duration bins Distribution**

# %%
ax=sns.countplot(x='duration_bins', data=d)
plt.xlabel('duration bins')
plt.ylabel('Frequency')
plt.title('duration bins Distribution')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=10)
plt.show()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
d
# Out:
#           airline   flight source_city departure_time stops arrival_time  \
# 0        SpiceJet  SG-8709       Delhi        Evening  zero        Night
# 1        SpiceJet  SG-8157       Delhi        Morning  zero      Morning
# 2        Air Asia   I5-764       Delhi        Morning  zero      Morning
# 3         Vistara   UK-995       Delhi        Morning  zero    Afternoon
# 4         Vistara   UK-963       Delhi        Morning  zero      Morning
# ...           ...      ...         ...            ...   ...          ...
# 301201    Vistara   UK-747       Delhi        Morning   one        Night
# 301202  Air India   AI-512       Delhi      Afternoon   one        Night
# 301203  Air India   AI-537       Delhi        Evening   one      Morning
# 301204    Vistara   UK-977       Delhi        Evening  zero        Night
# 301205    Vistara   UK-809       Delhi        Evening   one        Night
#
#        destination_city    class  duration  days_left    price       date  \
# ...

# %% [markdown]
# ## **Average Price by Month-Wise**

# %%
d['date'] = pd.to_datetime(d['date'], dayfirst=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13288\3173560290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['date'] = pd.to_datetime(d['date'], dayfirst=True)

# %%
# Calculate the average price by date
avg_price_by_date = d.groupby('date')['price'].mean()

# Create a line plot for average price by date
plt.figure(figsize=(10, 6))
plt.plot(avg_price_by_date.index, avg_price_by_date.values)
plt.title('Average Price by Month-Wise')
plt.xlabel('Date')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# ## **Price vs Date by Class**

# %%
plt.figure(figsize=(10, 6))
for class_type in d['class'].unique():
    class_d = d[d['class'] == class_type]
    plt.scatter(class_d['date'], class_d['price'], label=class_type)
plt.title('Price vs Date by Class')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## **Distribution of Price Bins**

# %%
plt.figure(figsize=(10,16))
d['price_bins'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Price Bins')
plt.show()

# %% [markdown]
# ## **Price Bins by Class**

# %%
plt.figure(figsize=(10,6))
pd.crosstab(d['class'], d['price_bins']).plot(kind='bar')
plt.title('Price Bins by Class')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## **Price Bins by Duration Bins**

# %%
plt.figure(figsize=(10,6))
pd.crosstab(d['duration_bins'], d['price_bins']).plot(kind='bar')
plt.title('Price Bins by Duration Bins')
plt.xlabel('Duration Bins')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## **Price Bins by Class and Duration Bins**

# %%
plt.figure(figsize=(10,6))
pd.crosstab([d['class'], d['duration_bins']], d['price_bins']).plot(kind='bar')
plt.title('Price Bins by Class and Duration Bins')
plt.xlabel('Class and Duration Bins')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,6))
ax=d['flight'].value_counts().head(10).plot(kind='bar')
plt.xlabel('Flight Number')
plt.ylabel('Count')
plt.title('Top 10 Most Frequent Flights')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=11)
plt.show()

# %%
d['flight'].value_counts().head(10)
# Out:
# flight
# UK-706    3235
# UK-772    2741
# UK-836    2651
# UK-720    2650
# UK-822    2573
# UK-828    2524
# UK-832    2490
# UK-874    2423
# UK-826    2404
# UK-838    2356
# Name: count, dtype: int64

# %% [markdown]
# ## **Top 5 Most Frequent Flights**

# %%
plt.figure(figsize=(10,6))
ax=d['flight'].value_counts().head(5).plot(kind='bar')
plt.xlabel('Flight Number')
plt.ylabel('Count')
plt.title('Top 5 Most Frequent Flights')
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), str(p.get_height()), 
            ha="center", va="bottom", size=12)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(y='arrival_time', data=d, order=d['arrival_time'].value_counts().index)
plt.title('ARRIVAL TIME AND NUMBER OF FLIGHTS')
plt.ylabel('ARRIVAL TIME')
plt.xlabel('COUNT OF FLIGHTS')
plt.show()
plt.figure(figsize=(8,6))
sns.countplot(y='departure_time',data=d, order=d['departure_time'].value_counts().index)
plt.title("DEPARTURE TIME AND NUMBER OF FLIGHTS")
plt.xlabel('number of flights')
plt.ylabel('departure time')
plt.show()

# %% [markdown]
# ## **Heat Map of Numerical Columns**

# %%
numerical_cols = ['duration', 'days_left', 'price']

# Create a heat map
plt.figure(figsize=(10, 8))
sns.heatmap(d[numerical_cols].corr(), annot=True, cmap='coolwarm', square=True)
plt.title('Heat Map of Numerical Columns')
plt.show()

# %% [markdown]
# # OUTLIERS

# %%
import pandas as pd
from scipy import stats


z_scores = stats.zscore(d['duration'])


outliers = np.abs(z_scores) > 2

print(d[outliers])
# Out:
#           airline  flight source_city departure_time stops arrival_time  \
# 65        Vistara  UK-817       Delhi        Evening   one        Night
# 66        Vistara  UK-813       Delhi        Evening   one        Night
# 82      Air India  AI-801       Delhi        Evening   one        Night
# 86      Air India  AI-764       Delhi        Evening   one        Night
# 114     Air India  AI-429       Delhi        Morning   one    Afternoon
# ...           ...     ...         ...            ...   ...          ...
# 301201    Vistara  UK-747       Delhi        Morning   one        Night
# 301202  Air India  AI-512       Delhi      Afternoon   one        Night
# 301203  Air India  AI-537       Delhi        Evening   one      Morning
# 301204    Vistara  UK-977       Delhi        Evening  zero        Night
# 301205    Vistara  UK-809       Delhi        Evening   one        Night
#
#        destination_city    class  duration  days_left    price       date  \
# ...

# %%
d.shape
# Out:
# (301177, 14)

# %%
d
# Out:
#           airline   flight source_city departure_time stops arrival_time  \
# 0        SpiceJet  SG-8709       Delhi        Evening  zero        Night
# 1        SpiceJet  SG-8157       Delhi        Morning  zero      Morning
# 2        Air Asia   I5-764       Delhi        Morning  zero      Morning
# 3         Vistara   UK-995       Delhi        Morning  zero    Afternoon
# 4         Vistara   UK-963       Delhi        Morning  zero      Morning
# ...           ...      ...         ...            ...   ...          ...
# 301201    Vistara   UK-747       Delhi        Morning   one        Night
# 301202  Air India   AI-512       Delhi      Afternoon   one        Night
# 301203  Air India   AI-537       Delhi        Evening   one      Morning
# 301204    Vistara   UK-977       Delhi        Evening  zero        Night
# 301205    Vistara   UK-809       Delhi        Evening   one        Night
#
#        destination_city    class  duration  days_left    price       date  \
# ...

# %%
import pandas as pd
from scipy import stats


z_scores = stats.zscore(d['duration'])


outliers = np.abs(z_scores) > 3

print(d[outliers])
# Out:
#           airline   flight source_city departure_time        stops  \
# 10540   Air India  AI-9887       Delhi        Morning  two_or_more
# 20464     Vistara   UK-815       Delhi        Morning  two_or_more
# 20467     Vistara   UK-801       Delhi        Morning  two_or_more
# 29417   Air India   AI-481       Delhi        Morning  two_or_more
# 29418   Air India   AI-435       Delhi        Morning  two_or_more
# ...           ...      ...         ...            ...          ...
# 301201    Vistara   UK-747       Delhi        Morning          one
# 301202  Air India   AI-512       Delhi      Afternoon          one
# 301203  Air India   AI-537       Delhi        Evening          one
# 301204    Vistara   UK-977       Delhi        Evening         zero
# 301205    Vistara   UK-809       Delhi        Evening          one
#
#        arrival_time destination_city    class  duration  days_left    price  \
# 10540       Evening        Bangalore  Economy     36.92          4  12321.0
# ...
